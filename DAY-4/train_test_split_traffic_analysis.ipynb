# %% [markdown]
# <a href="https://colab.research.google.com/github/Kamali1265/ML-Ops-Tasks/blob/main/DAY-4/train_test_split_traffic_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h2 style='color:purple' align='center'>Training And Testing Available Data</h2>

# %%
import pandas as pd

df = pd.read_csv("traffic_duration.csv")
df.head()
# Out:
#    vehicle_count  avg_speed  traffic_duration
# 0             50         60                10
# 1             80         55                15
# 2            100         50                20
# 3            120         48                25
# 4            150         45                30

# %%
import matplotlib.pyplot as plt

plt.scatter(df['vehicle_count'],df['traffic_duration'])

# %%
plt.scatter(df['avg_speed'],df['traffic_duration'])

# %%
X = df[['vehicle_count','avg_speed']]
X
# Out:
#     vehicle_count  avg_speed
# 0              50         60
# 1              80         55
# 2             100         50
# 3             120         48
# 4             150         45
# 5             180         40
# 6             200         38
# 7             230         35
# 8             250         32
# 9             300         30
# 10            350         28
# 11            400         25
# 12            450         22
# 13            500         20

# %%
y = df['traffic_duration']
y
# Out:
# 0      10
# 1      15
# 2      20
# 3      25
# 4      30
# 5      35
# 6      40
# 7      45
# 8      50
# 9      60
# 10     70
# 11     80
# 12     90
# 13    100
# Name: traffic_duration, dtype: int64

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(
    X,
    y,
    test_size=0.3
)

# %%
X_train
# Out:
#     vehicle_count  avg_speed
# 12            450         22
# 11            400         25
# 0              50         60
# 1              80         55
# 7             230         35
# 5             180         40
# 2             100         50
# 6             200         38
# 3             120         48

# %%
X_test
# Out:
#     vehicle_count  avg_speed
# 4             150         45
# 10            350         28
# 13            500         20
# 8             250         32
# 9             300         30

# %%
y_train
# Out:
# 12    90
# 11    80
# 0     10
# 1     15
# 7     45
# 5     35
# 2     20
# 6     40
# 3     25
# Name: traffic_duration, dtype: int64

# %%
y_test
# Out:
# 4      30
# 10     70
# 13    100
# 8      50
# 9      60
# Name: traffic_duration, dtype: int64

# %%
X_train,X_test,y_train,y_test = train_test_split(
    X,
    y,
    test_size=0.3,
    random_state=10
)

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()

model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
model.predict(X_test)
# Out:
# array([23.63205129, 45.67032189, 90.03687513, 39.64771612, 49.66308379])

# %%
model.score(X_test,y_test)
# Out:
# 0.9989108121850012
